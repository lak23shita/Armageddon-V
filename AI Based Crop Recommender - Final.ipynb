# %%
# import libraries
import boto3, re, sys, math, json, os, sagemaker, urllib.request
from sagemaker import get_execution_role
import numpy as np                                
import pandas as pd                               
import matplotlib.pyplot as plt                   
from IPython.display import Image                 
from IPython.display import display               
from time import gmtime, strftime                 
from sagemaker.predictor import csv_serializer   

# Define IAM role
role = get_execution_role()
prefix = 'sagemaker/DEMO-xgboost-dm'
containers = {'us-west-2': '433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest',
              'us-east-1': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
              'us-east-2': '825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest',
              'eu-west-1': '685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:latest',
              'ap-south-1': '720646828776.dkr.ecr.ap-south-1.amazonaws.com/xgboost:latest'} # each region has its XGBoost container
my_region = boto3.session.Session().region_name # set the region of the instance
print("Success - the MySageMakerInstance is in the " + my_region + " region. You will use the " + containers[my_region] + " container for your SageMaker endpoint.")
# Out:
# Success - the MySageMakerInstance is in the us-east-2 region. You will use the 825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest container for your SageMaker endpoint.

# %%
bucket_name = 'crop-recommender-armageddon-v' # <--- CHANGE THIS VARIABLE TO A UNIQUE NAME FOR YOUR BUCKET
s3 = boto3.resource('s3')
try:
    if  my_region == 'us-east-1':
      s3.create_bucket(Bucket=bucket_name)
    else: 
      s3.create_bucket(Bucket=bucket_name, CreateBucketConfiguration={ 'LocationConstraint': my_region })
    print('S3 bucket created successfully')
except Exception as e:
    print('S3 error: ',e)
# Out:
# S3 error:  An error occurred (BucketAlreadyOwnedByYou) when calling the CreateBucket operation: Your previous request to create the named bucket succeeded and you already own it.

# %% [markdown]
# Upload data to the Bucket first!

# %%
try:
  model_data = pd.read_csv('./Hackathon_data_30_Oct.csv',index_col=None)
  model_data1 = pd.read_csv('./Hackathon_data_30_Oct.csv',index_col=None)
  print('Success: Data loaded into dataframe.')
except Exception as e:
    print('Data load error: ',e)
# Out:
# Success: Data loaded into dataframe.

# %%
# set an output path where the trained model will be saved
prefix = 'xgboost-as-a-built-in-algo'
output_path ='s3://{}/{}/output'.format(bucket_name, prefix)
print(output_path)
# Out:
# s3://crop-recommender-armageddon-v/xgboost-as-a-built-in-algo/output

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='median')
model_data[['Production']] = imputer.fit_transform(model_data[['Production']])

# %%
model_data = model_data.fillna(0)
model_data = model_data.drop(['TOTAL'],axis = 1)
model_data = model_data.drop(['Crop_Year'],axis = 1)

# %%
model_data = model_data[model_data.Crop != 'Other Vegetables']
model_data = model_data[model_data.Crop != 'Oilseeds total']
model_data = model_data[model_data.Crop != 'Other  Rabi pulses']
model_data = model_data[model_data.Crop != 'Other Fresh Fruits']
model_data = model_data[model_data.Crop != 'Other Kharif pulses']
model_data = model_data[model_data.Crop != 'other oilseeds']
model_data = model_data[model_data.Crop != 'Other Cereals & Millets']

# %%
model_data1 = model_data1[model_data.Crop != 'Other Vegetables']
model_data1 = model_data1[model_data.Crop != 'Oilseeds total']
model_data1 = model_data1[model_data.Crop != 'Other  Rabi pulses']
model_data1 = model_data1[model_data.Crop != 'Other Fresh Fruits']
model_data1 = model_data1[model_data.Crop != 'Other Kharif pulses']
model_data1 = model_data1[model_data.Crop != 'other oilseeds']
model_data1 = model_data1[model_data.Crop != 'Other Cereals & Millets']
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
len(model_data.Crop.unique())
# Out:
# 54

# %%
model_data
# Out:
#                          State_Name District_Name       Season          Crop  \
# 0       Andaman and Nicobar Islands      NICOBARS  Whole Year       Arecanut
# 1       Andaman and Nicobar Islands      NICOBARS  Whole Year         Banana
# 2       Andaman and Nicobar Islands      NICOBARS  Whole Year   Black pepper
# 3       Andaman and Nicobar Islands      NICOBARS  Whole Year      Cashewnut
# 4       Andaman and Nicobar Islands      NICOBARS  Whole Year       Coconut
# ...                             ...           ...          ...           ...
# 123229                  West Bengal       PURULIA  Summer               Rice
# 123230                  West Bengal       PURULIA  Summer            Sesamum
# 123231                  West Bengal       PURULIA  Whole Year      Sugarcane
# 123232                  West Bengal       PURULIA  Winter               Rice
# 123233                  West Bengal       PURULIA  Winter            Sesamum
#
#              Area   Production  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec  ...  \
# 0          896.00       477.60   106.13   531.89  1794.44   650.92  ...
# 1          198.00       976.00   106.13   531.89  1794.44   650.92  ...
# 2           22.16         0.68   106.13   531.89  1794.44   650.92  ...
# 3          450.00        85.13   106.13   531.89  1794.44   650.92  ...
# 4        14358.00  59370000.00   106.13   531.89  1794.44   650.92  ...
# ...           ...          ...      ...      ...      ...      ...  ...
# 123229     306.00       801.00    27.53   183.07  1188.54   105.57  ...
# 123230     627.00       463.00    27.53   183.07  1188.54   105.57  ...
# 123231     324.00     16250.00    27.53   183.07  1188.54   105.57  ...
# 123232  279151.00    597899.00    27.53   183.07  1188.54   105.57  ...
# 123233     175.00        88.00    27.53   183.07  1188.54   105.57  ...
#
#         DIESEL PUMP  WIND MILLS  SOLAR PUMPS  MANUAL/ANIMAL      OTHERS  \
# 0           0.00000         0.0          0.0            1.0   26.333333
# 1           0.00000         0.0          0.0            1.0   26.333333
# 2           0.00000         0.0          0.0            1.0   26.333333
# 3           0.00000         0.0          0.0            1.0   26.333333
# 4           0.00000         0.0          0.0            1.0   26.333333
# ...             ...         ...          ...            ...         ...
# 123229  22092.66667         0.0          0.0            0.0  710.388889
# 123230  22092.66667         0.0          0.0            0.0  710.388889
# 123231  22092.66667         0.0          0.0            0.0  710.388889
# 123232  22092.66667         0.0          0.0            0.0  710.388889
# 123233  22092.66667         0.0          0.0            0.0  710.388889
#
#         Soil Type       N      OC       P       K
# 0           Sandy  0.9911  0.6596  0.7816  0.8989
# 1           Sandy  0.9911  0.6596  0.7816  0.8989
# 2           Sandy  0.9911  0.6596  0.7816  0.8989
# 3           Sandy  0.9911  0.6596  0.7816  0.8989
# 4           Sandy  0.9911  0.6596  0.7816  0.8989
# ...           ...     ...     ...     ...     ...
# 123229   Alluvial  0.5027  0.5029  0.1125  0.0259
# 123230   Alluvial  0.5027  0.5029  0.1125  0.0259
# 123231   Alluvial  0.5027  0.5029  0.1125  0.0259
# 123232   Alluvial  0.5027  0.5029  0.1125  0.0259
# 123233   Alluvial  0.5027  0.5029  0.1125  0.0259
#
# [119272 rows x 26 columns]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
model_data['State_Name'] = le.fit_transform(model_data['State_Name'])
le1 = preprocessing.LabelEncoder()
model_data['District_Name'] = le1.fit_transform(model_data['District_Name'])
le2 = preprocessing.LabelEncoder()
model_data['Soil Type'] = le2.fit_transform(model_data['Soil Type'])
le3 = preprocessing.LabelEncoder()
model_data['Crop'] = le3.fit_transform(model_data['Crop'])
le4 = preprocessing.LabelEncoder()
model_data['Season'] = le4.fit_transform(model_data['Season'])

# %%
le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
le_name_mapping1 = dict(zip(le1.classes_, le1.transform(le1.classes_)))
le_name_mapping2 = dict(zip(le2.classes_, le2.transform(le2.classes_)))
le_name_mapping3 = dict(zip(le3.classes_, le3.transform(le3.classes_)))
le_name_mapping4 = dict(zip(le4.classes_, le4.transform(le4.classes_)))

# %%
le_name_mapping2
# Out:
# {'Alluvial': 0, 'Black': 1, 'Laterite': 2, 'Red': 3, 'Sandy': 4}

# %%
len(model_data.columns)
# Out:
# 28

# %%
'''from sklearn.preprocessing import StandardScaler
# numerical features
num_cols = ['Crop_Year','State_Name','District_Name', 'Season','Soil Type','Area','Production','Jan-Feb','Mar-May','Jun-Sep','Oct-Dec','0-20 mts','20-40 mts','40-60 mts','60-70 mts','GREATER THAN 70 mts','ELECTRIC PUMP','DIESEL PUMP','WIND MILLS','SOLAR PUMPS','MANUAL/ANIMAL','OTHERS','TOTAL']
for i in num_cols:    
    scale = StandardScaler().fit(model_data[[i]])
    model_data[i] = scale.transform(model_data[[i]])'''
# Out:
# "from sklearn.preprocessing import StandardScaler\n# numerical features\nnum_cols = ['Crop_Year','State_Name','District_Name', 'Season','Soil Type','Area','Production','Jan-Feb','Mar-May','Jun-Sep','Oct-Dec','0-20 mts','20-40 mts','40-60 mts','60-70 mts','GREATER THAN 70 mts','ELECTRIC PUMP','DIESEL PUMP','WIND MILLS','SOLAR PUMPS','MANUAL/ANIMAL','OTHERS','TOTAL']\nfor i in num_cols:    \n    scale = StandardScaler().fit(model_data[[i]])\n    model_data[i] = scale.transform(model_data[[i]])"

# %%
model_data1.Crop.unique()
# Out:
# array(['Arecanut', 'Banana', 'Black pepper', 'Cashewnut', 'Coconut ',
#        'Dry chillies', 'Dry ginger', 'Sugarcane', 'Sweet potato',
#        'Tapioca', 'Turmeric', 'Rice', 'Maize', 'Moong(Green Gram)',
#        'Urad', 'Arhar/Tur', 'Groundnut', 'Sunflower', 'Bajra',
#        'Castor seed', 'Cotton(lint)', 'Horse-gram', 'Jowar', 'Onion',
#        'Ragi', 'Small millets', 'Gram', 'Linseed', 'Safflower', 'Wheat',
#        'Coriander', 'Soyabean', 'Tobacco', 'Rapeseed &Mustard', 'Mesta',
#        'Potato', 'Cowpea(Lobia)', 'Brinjal', 'Mango', 'Papaya', 'Tomato',
#        'Sesamum', 'Niger seed', 'Sannhamp', 'Garlic', 'Jute', 'Masoor',
#        'Peas & beans (Pulses)', 'Paddy', 'Barley', 'Khesari', 'Guar seed',
#        'Moth', 'Cardamom'], dtype=object)

# %%
len(model_data.Crop.unique())
# Out:
# 54

# %%
train_data, test_data = np.split(model_data.sample(frac=1, random_state=1729), [int(0.8 * len(model_data))])
print(train_data.shape, test_data.shape)
# Out:
# (95417, 26) (23855, 26)

# %%
test_data.Crop.value_counts()
# Out:
# 39    1535
# 25    1520
# 29    1187
# 52    1018
# 42     950
# 18     922
# 45     814
# 53     811
# 38     775
# 1      761
# 32     757
# 17     748
# 36     705
# 21     660
# 14     652
# 27     525
# 2      505
# 46     503
# 35     499
# 37     446
# 12     439
# 20     435
# 43     429
# 51     419
# 24     413
# 47     410
# 4      372
# 3      359
# 9      351
# 16     346
# 11     332
# 15     297
# 44     295
# 49     257
# 41     232
# 10     212
# 31     201
# 28     195
# 19     173
# 0      167
# 22     166
# 23     159
# 48     156
# 5      138
# 8      116
# 40     114
# 13     111
# 33      66
# 30      63
# 7       48
# 34      36
# 6       25
# 26      15
# 50      15
# Name: Crop, dtype: int64

# %%
len(test_data.columns)
# Out:
# 26

# %%
pd.concat([train_data['Crop'], train_data.drop(['Crop'], axis=1)], axis=1).to_csv('train.csv', index=False, header=False)
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
s3_input_train = sagemaker.s3_input(s3_data='s3://{}/{}/train'.format(bucket_name, prefix), content_type='csv')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
pd.concat([test_data['Crop'], test_data.drop(['Crop'], axis=1)], axis=1).to_csv('test.csv', index=False, header=False)
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'test/test.csv')).upload_file('test.csv')
s3_input_test = sagemaker.s3_input(s3_data='s3://{}/{}/test'.format(bucket_name, prefix), content_type='csv')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri 
container = get_image_uri(boto3.Session().region_name,
                          'xgboost', 
                          repo_version='1.0-1')
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.

# %%
sess = sagemaker.Session()
xgb = sagemaker.estimator.Estimator(containers[my_region],role, train_instance_count=1, 
                                        train_instance_type='ml.m4.xlarge',
                                        output_path='s3://{}/{}/output'.format(bucket_name, prefix),
                                        sagemaker_session=sess,train_use_spot_instances=True,
                                        train_max_run=300,
                                        train_max_wait=2000)
xgb.set_hyperparameters(learning_rate = 0.13, num_round=25, objective='multi:softprob',
                        nthread=1,max_depth=7,eta=0.2,gamma=0.3,min_child_weight=1,
                        subsample=0.7,silent=0,num_class=54,scale_pos_weight = 1,n_estimators = 750)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %%
xgb.fit({'train': s3_input_train,'validation': s3_input_test})
# Out:
# 2020-10-31 09:17:31 Starting - Starting the training job...
# 2020-10-31 09:17:33 Starting - Launching requested ML instances......
# 2020-10-31 09:18:35 Starting - Preparing the instances for training......
# 2020-10-31 09:19:59 Downloading - Downloading input data...
# 2020-10-31 09:20:25 Training - Training image download completed. Training in progress.Arguments: train
# [2020-10-31:09:20:26:INFO] Running standalone xgboost training.
# [2020-10-31:09:20:26:INFO] File size need to be processed in the node: 22.5mb. Available memory size in the node: 8472.18mb
# [2020-10-31:09:20:26:INFO] Determined delimiter of CSV input is ','
# [09:20:26] S3DistributionType set as FullyReplicated
# [09:20:26] 95417x25 matrix with 2385425 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2020-10-31:09:20:26:INFO] Determined delimiter of CSV input is ','
# [09:20:26] S3DistributionType set as FullyReplicated
# [09:20:26] 23855x25 matrix with 596375 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [09:20:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 10 pruned nodes, max_depth=7
# [09:20:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 182 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 6 pruned nodes, max_depth=7
# [09:20:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [09:20:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=7
# [0]#011train-merror:0.646897#011validation-merror:0.67139
# [09:20:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 6 pruned nodes, max_depth=7
# [09:20:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 6 pruned nodes, max_depth=7
# [09:20:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=6
# [09:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=7
# [1]#011train-merror:0.607774#011validation-merror:0.640411
# [09:20:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 8 pruned nodes, max_depth=7
# [09:20:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 6 pruned nodes, max_depth=7
# [09:20:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=6
# [09:20:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 6 pruned nodes, max_depth=7
# [09:20:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 6 pruned nodes, max_depth=7
# [09:20:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 4 pruned nodes, max_depth=7
# [09:20:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 6 pruned nodes, max_depth=7
# [09:20:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 2 pruned nodes, max_depth=7
# [09:20:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=7
# [09:20:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=7
# [2]#011train-merror:0.583187#011validation-merror:0.622218
# [09:21:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 6 pruned nodes, max_depth=7
# [09:21:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 6 pruned nodes, max_depth=7
# [09:21:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 6 pruned nodes, max_depth=7
# [09:21:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 6 pruned nodes, max_depth=7
# [09:21:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 6 pruned nodes, max_depth=7
# [09:21:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 6 pruned nodes, max_depth=7
# [09:21:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 8 pruned nodes, max_depth=7
# [09:21:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 4 pruned nodes, max_depth=7
# [3]#011train-merror:0.566555#011validation-merror:0.610606
# [09:21:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 10 pruned nodes, max_depth=7
# [09:21:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 10 pruned nodes, max_depth=7
# [09:21:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=7
# [4]#011train-merror:0.552847#011validation-merror:0.600293
# [09:21:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 6 pruned nodes, max_depth=7
# [09:21:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 6 pruned nodes, max_depth=7
# [09:21:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 6 pruned nodes, max_depth=7
# [09:21:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 2 pruned nodes, max_depth=7
# [5]#011train-merror:0.539212#011validation-merror:0.587969
# [09:21:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 10 pruned nodes, max_depth=7
# [09:21:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 8 pruned nodes, max_depth=7
# [09:21:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=7
# [6]#011train-merror:0.52934#011validation-merror:0.581597
# [09:21:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 6 pruned nodes, max_depth=7
# [09:21:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 4 pruned nodes, max_depth=7
# [09:21:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 8 pruned nodes, max_depth=7
# [09:21:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 0 pruned nodes, max_depth=7
# [09:21:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 2 pruned nodes, max_depth=7
# [09:21:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# ...
# [09:24:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=7
# [09:24:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 8 pruned nodes, max_depth=7
# [09:24:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 12 pruned nodes, max_depth=7
# [09:24:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 6 pruned nodes, max_depth=7
# [09:24:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 6 pruned nodes, max_depth=7
# [09:24:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=7
# [09:24:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 12 pruned nodes, max_depth=7
# [09:24:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 4 pruned nodes, max_depth=7
# [09:24:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 6 pruned nodes, max_depth=7
# [09:24:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 4 pruned nodes, max_depth=7
# [09:24:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 4 pruned nodes, max_depth=7
# [09:24:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 4 pruned nodes, max_depth=7
# [09:24:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 4 pruned nodes, max_depth=7
# [09:24:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 8 pruned nodes, max_depth=7
# [09:24:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 4 pruned nodes, max_depth=7
# [09:24:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 4 pruned nodes, max_depth=7
# [09:24:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=7
# [22]#011train-merror:0.426454#011validation-merror:0.518717
# [09:24:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 8 pruned nodes, max_depth=7
# [09:24:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 8 pruned nodes, max_depth=7
# [09:24:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 8 pruned nodes, max_depth=7
# [09:24:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 4 pruned nodes, max_depth=7
# [09:24:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 14 pruned nodes, max_depth=7
# [09:24:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 6 pruned nodes, max_depth=7
# [09:24:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 4 pruned nodes, max_depth=7
# [09:24:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 4 pruned nodes, max_depth=7
# [09:24:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 4 pruned nodes, max_depth=7
# [09:24:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 4 pruned nodes, max_depth=7
# [09:24:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 10 pruned nodes, max_depth=7
# [09:24:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 8 pruned nodes, max_depth=7
# [09:24:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 6 pruned nodes, max_depth=7
# [09:24:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 14 pruned nodes, max_depth=7
# [09:24:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 8 pruned nodes, max_depth=7
# [09:24:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 6 pruned nodes, max_depth=7
# [09:24:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 12 pruned nodes, max_depth=7
# [09:24:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 10 pruned nodes, max_depth=7
# [09:24:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 10 pruned nodes, max_depth=7
# [09:24:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 6 pruned nodes, max_depth=7
# [09:24:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 6 pruned nodes, max_depth=7
# [09:24:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 4 pruned nodes, max_depth=7
# [09:24:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 8 pruned nodes, max_depth=7
# [09:24:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 4 pruned nodes, max_depth=7
# [09:24:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 2 pruned nodes, max_depth=7
# [23]#011train-merror:0.420795#011validation-merror:0.515531
# [09:24:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 4 pruned nodes, max_depth=7
# [09:24:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 6 pruned nodes, max_depth=7
# [09:24:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 10 pruned nodes, max_depth=7
# [09:24:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 10 pruned nodes, max_depth=7
# [09:24:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 10 pruned nodes, max_depth=7
# [09:24:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 4 pruned nodes, max_depth=7
# [09:24:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 6 pruned nodes, max_depth=7
# [09:24:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 4 pruned nodes, max_depth=7
# [09:24:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 6 pruned nodes, max_depth=7
# [09:24:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 6 pruned nodes, max_depth=7
# [09:24:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 4 pruned nodes, max_depth=7
# [09:24:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 2 pruned nodes, max_depth=7
# [09:24:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 6 pruned nodes, max_depth=7
# [09:24:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=7
# [09:24:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=7
# [09:25:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 2 pruned nodes, max_depth=7
# [09:25:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 6 pruned nodes, max_depth=7
# [09:25:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 10 pruned nodes, max_depth=7
# [09:25:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 4 pruned nodes, max_depth=7
# [09:25:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 14 pruned nodes, max_depth=7
# [09:25:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=7
# [09:25:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=7
# [09:25:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 8 pruned nodes, max_depth=7
# [09:25:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 4 pruned nodes, max_depth=7
# [09:25:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 12 pruned nodes, max_depth=7
# [09:25:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 6 pruned nodes, max_depth=7
# [09:25:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 2 pruned nodes, max_depth=7
# [09:25:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=7
# [09:25:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 190 extra nodes, 2 pruned nodes, max_depth=7
# [09:25:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=7
# [09:25:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=7
# [09:25:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 2 pruned nodes, max_depth=7
# [09:25:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 8 pruned nodes, max_depth=7
# [09:25:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 4 pruned nodes, max_depth=7
# [09:25:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 6 pruned nodes, max_depth=7
# [09:25:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 18 pruned nodes, max_depth=7
# [09:25:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=7
# [09:25:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 2 pruned nodes, max_depth=7
# [09:25:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 10 pruned nodes, max_depth=7
# [09:25:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=7
# [24]#011train-merror:0.41588#011validation-merror:0.512094
#
# 2020-10-31 09:25:35 Uploading - Uploading generated training model
# 2020-10-31 09:25:35 Completed - Training job completed
# Training seconds: 336
# Billable seconds: 69
# Managed Spot Training savings: 79.5%

# %%
xgb_predictor = xgb.deploy(initial_instance_count=1,instance_type='ml.m4.xlarge')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# -------------!

# %%
test_data_array = test_data.drop(['Crop'], axis=1).values #load the data into an array
xgb_predictor.content_type = 'text/csv' # set the data type for an inference
xgb_predictor.serializer = csv_serializer # set the serializer type

# %%
test_data_array[1]
# Out:
# array([3.20000000e+01, 1.27000000e+02, 3.00000000e+00, 1.85000000e+02,
#        1.56000000e+02, 2.75300000e+01, 1.83070000e+02, 1.18854000e+03,
#        1.05570000e+02, 1.01076111e+04, 1.25443889e+04, 2.72455556e+03,
#        1.44805556e+03, 1.05183333e+03, 5.07338889e+03, 2.20926667e+04,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.10388889e+02,
#        0.00000000e+00, 5.54200000e-01, 3.39300000e-01, 2.38000000e-02,
#        5.29800000e-01])

# %%
test_data_array_top50 = test_data_array[:50]

# %%
test_data_array
# Out:
# array([[2.100e+01, 6.380e+02, 2.000e+00, ..., 4.140e-02, 8.598e-01,
#         2.415e-01],
#        [3.200e+01, 1.270e+02, 3.000e+00, ..., 3.393e-01, 2.380e-02,
#         5.298e-01],
#        [2.000e+00, 5.910e+02, 4.000e+00, ..., 0.000e+00, 3.900e-01,
#         1.867e-01],
#        ...,
#        [1.700e+01, 4.890e+02, 1.000e+00, ..., 4.300e-03, 6.007e-01,
#         2.487e-01],
#        [1.900e+01, 1.750e+02, 4.000e+00, ..., 3.710e-02, 3.951e-01,
#         2.667e-01],
#        [1.000e+00, 2.730e+02, 2.000e+00, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]])

# %%
predictions = xgb_predictor.predict(test_data_array[3])
predictions_array = np.fromstring(predictions[1:], sep=',') # and turn the prediction into an array
print(predictions_array.shape)
# Out:
# (54,)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:2: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   from ipykernel import kernelapp as app

# %%
test_data_array[3]
# Out:
# array([1.40000000e+01, 3.18000000e+02, 2.00000000e+00, 3.50000000e+01,
#        1.13000000e+02, 7.82333333e+00, 1.53436667e+02, 1.46625667e+03,
#        2.02410000e+02, 1.17544444e+03, 3.60629630e+02, 1.87833333e+03,
#        8.01403704e+03, 1.57281111e+04, 2.60960741e+04, 1.39592593e+02,
#        1.48888889e+01, 6.96296296e+00, 1.01851852e+01, 8.88851852e+02,
#        3.00000000e+00, 5.90000000e-02, 1.37500000e-01, 4.75300000e-01,
#        2.95700000e-01])

# %%
predictions_array
# Out:
# array([0.00230869, 0.00179185, 0.00389081, 0.00149491, 0.00150536,
#        0.00252819, 0.00148839, 0.00160957, 0.00171915, 0.00175507,
#        0.00150768, 0.00198936, 0.00864594, 0.01181125, 0.25863007,
#        0.00197079, 0.00320297, 0.04251517, 0.0509109 , 0.00150684,
#        0.02064265, 0.0210575 , 0.00149964, 0.00187044, 0.01508354,
#        0.10104819, 0.00155443, 0.00177081, 0.00174031, 0.0125432 ,
#        0.00150217, 0.00150629, 0.03274722, 0.00149017, 0.00148877,
#        0.02757967, 0.09584876, 0.09302676, 0.02403227, 0.04915063,
#        0.01425589, 0.00259164, 0.00396421, 0.00201148, 0.00152871,
#        0.00155392, 0.01837688, 0.00365363, 0.00333777, 0.00338595,
#        0.00148806, 0.0022618 , 0.0159847 , 0.015639  ])

# %%
predictions_array = np.array([predictions_array])

# %%
predictions_array
# Out:
# array([[0.00230869, 0.00179185, 0.00389081, 0.00149491, 0.00150536,
#         0.00252819, 0.00148839, 0.00160957, 0.00171915, 0.00175507,
#         0.00150768, 0.00198936, 0.00864594, 0.01181125, 0.25863007,
#         0.00197079, 0.00320297, 0.04251517, 0.0509109 , 0.00150684,
#         0.02064265, 0.0210575 , 0.00149964, 0.00187044, 0.01508354,
#         0.10104819, 0.00155443, 0.00177081, 0.00174031, 0.0125432 ,
#         0.00150217, 0.00150629, 0.03274722, 0.00149017, 0.00148877,
#         0.02757967, 0.09584876, 0.09302676, 0.02403227, 0.04915063,
#         0.01425589, 0.00259164, 0.00396421, 0.00201148, 0.00152871,
#         0.00155392, 0.01837688, 0.00365363, 0.00333777, 0.00338595,
#         0.00148806, 0.0022618 , 0.0159847 , 0.015639  ]])

# %%
n = 54
top_n_pred = np.argsort(predictions_array, axis=1)[:,-n :]

# %%
class_labels = model_data.Crop.unique()

# %%
class_labels
# Out:
# array(['Arecanut', 'Banana', 'Black pepper', 'Cashewnut', 'Coconut ',
#        'Dry chillies', 'Dry ginger', 'Sugarcane', 'Sweet potato',
#        'Tapioca', 'Turmeric', 'Rice', 'Maize', 'Moong(Green Gram)',
#        'Urad', 'other oilseeds', 'Arhar/Tur', 'Groundnut', 'Sunflower',
#        'Bajra', 'Castor seed', 'Cotton(lint)', 'Horse-gram', 'Jowar',
#        'Onion', 'Other Kharif pulses', 'Ragi', 'Small millets', 'Gram',
#        'Linseed', 'Safflower', 'Wheat', 'Coriander', 'Soyabean',
#        'Tobacco', 'Rapeseed &Mustard', 'Mesta', 'Potato', 'Cowpea(Lobia)',
#        'Brinjal', 'Mango', 'Papaya', 'Tomato', 'Other  Rabi pulses',
#        'Sesamum', 'Niger seed', 'Sannhamp', 'Garlic', 'Oilseeds total',
#        'Jute', 'Masoor', 'Peas & beans (Pulses)', 'Paddy', 'Barley',
#        'Khesari', 'Guar seed', 'Other Fresh Fruits', 'Other Vegetables',
#        'Moth', 'Other Cereals & Millets', 'Cardamom'], dtype=object)

# %%
top_n_pred
# Out:
# array([[50,  6, 34, 33,  3, 22, 30,  4, 31, 19, 10, 44, 45, 26,  7,  8,
#         28,  9, 27,  1, 23, 15, 11, 43, 51,  0,  5, 41, 16, 48, 49, 47,
#          2, 42, 12, 13, 29, 40, 24, 53, 52, 46, 20, 21, 38, 35, 32, 17,
#         39, 18, 37, 36, 25, 14]])

# %%
class_labels[top_n_pred]
# Out:
# array([['Masoor', 'Dry ginger', 'Tobacco', 'Soyabean', 'Cashewnut',
#         'Horse-gram', 'Safflower', 'Coconut ', 'Wheat', 'Bajra',
#         'Turmeric', 'Sesamum', 'Niger seed', 'Ragi', 'Sugarcane',
#         'Sweet potato', 'Gram', 'Tapioca', 'Small millets', 'Banana',
#         'Jowar', 'other oilseeds', 'Rice', 'Other  Rabi pulses',
#         'Peas & beans (Pulses)', 'Arecanut', 'Dry chillies', 'Papaya',
#         'Arhar/Tur', 'Oilseeds total', 'Jute', 'Garlic', 'Black pepper',
#         'Tomato', 'Maize', 'Moong(Green Gram)', 'Linseed', 'Mango',
#         'Onion', 'Barley', 'Paddy', 'Sannhamp', 'Castor seed',
#         'Cotton(lint)', 'Cowpea(Lobia)', 'Rapeseed &Mustard',
#         'Coriander', 'Groundnut', 'Brinjal', 'Sunflower', 'Potato',
#         'Mesta', 'Other Kharif pulses', 'Urad']], dtype=object)

# %%
sorted( zip(model_data1.Crop.unique(), predictions_array[0] ),key=lambda x:x[1])[-n:]
# Out:
# [('Khesari', 0.0014880596427246928),
#  ('Dry ginger', 0.0014883875846862793),
#  ('Mesta', 0.0014887652359902859),
#  ('Rapeseed &Mustard', 0.0014901658287271857),
#  ('Cashewnut', 0.0014949063770473003),
#  ('Jowar', 0.0014996420359238982),
#  ('Coriander', 0.0015021741855889559),
#  ('Coconut ', 0.0015053563984110951),
#  ('Soyabean', 0.001506292843259871),
#  ('Castor seed', 0.0015068387147039175),
#  ('Turmeric', 0.0015076824929565191),
#  ('Garlic', 0.0015287109417840838),
#  ('Jute', 0.0015539187006652355),
#  ('Gram', 0.0015544277848675847),
#  ('Sugarcane', 0.0016095747705549002),
#  ('Sweet potato', 0.0017191546503454447),
#  ('Safflower', 0.0017403105739504099),
#  ('Tapioca', 0.0017550685442984104),
#  ('Linseed', 0.001770805916748941),
#  ('Banana', 0.0017918547382578254),
#  ('Onion', 0.0018704435788094997),
#  ('Arhar/Tur', 0.0019707882311195135),
#  ('Rice', 0.0019893620628863573),
#  ('Sannhamp', 0.002011484932154417),
#  ('Guar seed', 0.0022618041839450598),
#  ('Arecanut', 0.002308690920472145),
#  ('Dry chillies', 0.0025281880516558886),
#  ('Sesamum', 0.002591641154140234),
#  ('Groundnut', 0.0032029743306338787),
#  ('Paddy', 0.003337773261591792),
#  ('Barley', 0.0033859475515782833),
#  ('Peas & beans (Pulses)', 0.0036536320112645626),
#  ('Black pepper', 0.003890808904543519),
#  ('Niger seed', 0.0039642066694796085),
#  ('Maize', 0.00864594429731369),
#  ('Moong(Green Gram)', 0.011811248026788235),
#  ('Wheat', 0.012543201446533203),
#  ('Tomato', 0.014255888760089874),
#  ('Ragi', 0.015083538368344307),
#  ('Cardamom', 0.01563899964094162),
#  ('Moth', 0.01598469913005829),
#  ('Masoor', 0.018376879394054413),
#  ('Cotton(lint)', 0.020642653107643127),
#  ('Horse-gram', 0.021057503297924995),
#  ('Mango', 0.024032266810536385),
#  ('Potato', 0.027579667046666145),
#  ('Tobacco', 0.03274722397327423),
#  ('Sunflower', 0.04251517355442047),
#  ('Papaya', 0.04915063455700874),
#  ('Bajra', 0.05091090127825737),
#  ('Brinjal', 0.09302676469087601),
#  ('Cowpea(Lobia)', 0.09584876149892807),
#  ('Small millets', 0.10104818642139435),
#  ('Urad', 0.25863006711006165)]

# %%
test_data.columns
# Out:
# Index(['State_Name', 'District_Name', 'Season', 'Crop', 'Area', 'Production',
#        'Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec', '0-20 mts', '20-40 mts',
#        '40-60 mts', '60-70 mts', 'GREATER THAN 70 mts', 'ELECTRIC PUMP',
#        'DIESEL PUMP', 'WIND MILLS', 'SOLAR PUMPS', 'MANUAL/ANIMAL', 'OTHERS',
#        'Soil Type', 'N', 'OC', 'P', 'K'],
#       dtype='object')

# %%
le_name_mapping3
# Out:
# {'Arecanut': 0,
#  'Arhar/Tur': 1,
#  'Bajra': 2,
#  'Banana': 3,
#  'Barley': 4,
#  'Black pepper': 5,
#  'Brinjal': 6,
#  'Cardamom': 7,
#  'Cashewnut': 8,
#  'Castor seed': 9,
#  'Coconut ': 10,
#  'Coriander': 11,
#  'Cotton(lint)': 12,
#  'Cowpea(Lobia)': 13,
#  'Dry chillies': 14,
#  'Dry ginger': 15,
#  'Garlic': 16,
#  'Gram': 17,
#  'Groundnut': 18,
#  'Guar seed': 19,
#  'Horse-gram': 20,
#  'Jowar': 21,
#  'Jute': 22,
#  'Khesari': 23,
#  'Linseed': 24,
#  'Maize': 25,
#  'Mango': 26,
#  'Masoor': 27,
#  'Mesta': 28,
#  'Moong(Green Gram)': 29,
#  'Moth': 30,
#  'Niger seed': 31,
#  'Onion': 32,
#  'Paddy': 33,
#  'Papaya': 34,
#  'Peas & beans (Pulses)': 35,
#  'Potato': 36,
#  'Ragi': 37,
#  'Rapeseed &Mustard': 38,
#  'Rice': 39,
#  'Safflower': 40,
#  'Sannhamp': 41,
#  'Sesamum': 42,
#  'Small millets': 43,
#  'Soyabean': 44,
#  'Sugarcane': 45,
#  'Sunflower': 46,
#  'Sweet potato': 47,
#  'Tapioca': 48,
#  'Tobacco': 49,
#  'Tomato': 50,
#  'Turmeric': 51,
#  'Urad': 52,
#  'Wheat': 53}

# %%
model_data1.Crop.unique()
# Out:
# array(['Arecanut', 'Banana', 'Black pepper', 'Cashewnut', 'Coconut ',
#        'Dry chillies', 'Dry ginger', 'Sugarcane', 'Sweet potato',
#        'Tapioca', 'Turmeric', 'Rice', 'Maize', 'Moong(Green Gram)',
#        'Urad', 'Arhar/Tur', 'Groundnut', 'Sunflower', 'Bajra',
#        'Castor seed', 'Cotton(lint)', 'Horse-gram', 'Jowar', 'Onion',
#        'Ragi', 'Small millets', 'Gram', 'Linseed', 'Safflower', 'Wheat',
#        'Coriander', 'Soyabean', 'Tobacco', 'Rapeseed &Mustard', 'Mesta',
#        'Potato', 'Cowpea(Lobia)', 'Brinjal', 'Mango', 'Papaya', 'Tomato',
#        'Sesamum', 'Niger seed', 'Sannhamp', 'Garlic', 'Jute', 'Masoor',
#        'Peas & beans (Pulses)', 'Paddy', 'Barley', 'Khesari', 'Guar seed',
#        'Moth', 'Cardamom'], dtype=object)

# %%
'''sagemaker.Session().delete_endpoint(xgb_predictor.endpoint)
bucket_to_delete = boto3.resource('s3').Bucket(bucket_name)
bucket_to_delete.objects.all().delete()'''
